# %%
import seaborn as sns
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
train=pd.read_csv('train.csv')

# %%
test=pd.read_csv('test.csv')

# %%
print(train.shape)
print(test.shape)
# Out:
# (595212, 60)
# (892816, 58)

# %%
train['ps_car_13_x_ps_reg_03'] = train['ps_car_13'] * train['ps_reg_03']

# %%
print(train.corr()['target'])
# Out:
# id                      -0.000188
# target                   1.000000
# ps_ind_01                0.018570
# ps_ind_02_cat            0.004534
# ps_ind_03                0.008360
# ps_ind_04_cat            0.009360
# ps_ind_05_cat            0.029165
# ps_ind_06_bin           -0.034017
# ps_ind_07_bin            0.034218
# ps_ind_08_bin            0.013147
# ps_ind_09_bin           -0.008237
# ps_ind_10_bin            0.001815
# ps_ind_11_bin            0.002028
# ps_ind_12_bin            0.007810
# ps_ind_13_bin            0.002460
# ps_ind_14                0.007443
# ps_ind_15               -0.021506
# ps_ind_16_bin           -0.027778
# ps_ind_17_bin            0.037053
# ps_ind_18_bin            0.004555
# ps_reg_01                0.022888
# ps_reg_02                0.034800
# ps_reg_03                0.030888
# ps_car_01_cat            0.016256
# ps_car_02_cat           -0.031534
# ps_car_03_cat            0.032401
# ps_car_04_cat            0.032900
# ...

# %%
sns.jointplot(x='ps_car_13_x_ps_reg_03',y='target',data=train)
plt.show()

# %%
sns.jointplot(x='ps_car_13_x_ps_reg_03',y='target',data=train,kind='kde')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kernels.py:128: RuntimeWarning: divide by zero encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kernels.py:128: RuntimeWarning: invalid value encountered in true_divide
#   return (1. / np.sqrt(2 * np.pi)) * np.exp(-(Xi - x)**2 / (h**2 * 2.))
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\_kernel_base.py:514: RuntimeWarning: invalid value encountered in true_divide
#   dens = Kval.prod(axis=1) / np.prod(bw[iscontinuous])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-131b1c1c3cb3> in <module>()
# ----> 1 sns.jointplot(x='ps_car_13_x_ps_reg_03',y='target',data=train,kind='kde')
#       2 plt.show()
#
# ...

# %%
sns.boxplot(x='target',y='ps_car_13',data=train)
plt.show()

# %%
sns.lmplot(x='target', y='ps_car_13', data=train,fit_reg=False)
plt.show()

# %%
sns.violinplot(x='ps_car_13',y='target',data=train)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-c3ec7fc08c4c> in <module>()
# ----> 1 sns.violinplot(x='ps_car_13',y='target',data=train)
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2348         ax = plt.gca()
#    2349
# -> 2350     plotter.plot(ax)
#    2351     return ax
#    2352
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax)
#    1070     def plot(self, ax):
#    1071         """Make the violin plot."""
# -> 1072         self.draw_violins(ax)
#    1073         self.annotate_axes(ax)
#    1074         if self.orient == "h":
#
# ...

# %%
sns.heatmap(train.corr())
plt.show()

# %%
sns.pairplot(train)
plt.show()
